# %%
import numpy as np
import pandas as pd

# %%
clase_1 = pd.read_csv("./data/clase_1.csv", sep = ";")
clase_1
# Out:
#                   Nombre                           Email   Promoción  \
# 0           Jafet Casals          Jafet_Casals@gmail.com  Septiembre
# 1       Jorge Manzanares      Jorge_Manzanares@gmail.com  Septiembre
# 2          Onofre Adadia         Onofre_Adadia@gmail.com  Septiembre
# 3           Merche Prada          Merche_Prada@gmail.com  Septiembre
# 4           Pilar Abella          Pilar_Abella@gmail.com  Septiembre
# 5           Leoncio Tena          Leoncio_Tena@gmail.com  Septiembre
# 6        Odalys Torrijos       Odalys_Torrijos@gmail.com  Septiembre
# 7       Eduardo Caparrós      Eduardo_Caparrós@gmail.com  Septiembre
# 8     Ignacio Goicoechea    Ignacio_Goicoechea@gmail.com  Septiembre
# 9      Clementina Santos     Clementina_Santos@gmail.com  Septiembre
# 10         Daniela Falcó         Daniela_Falcó@gmail.com  Septiembre
# 11         Abraham Vélez         Abraham_Vélez@gmail.com  Septiembre
# 12  Maximiliano Menéndez  Maximiliano_Menéndez@gmail.com  Septiembre
# ...

# %%
clase_2 = pd.read_csv("./data/clase_2.csv", sep = ";")
clase_2
# Out:
#               Nombre                        Email Promoción Fecha_comienzo  \
# 0  Guillermo Borrego  Guillermo_Borrego@gmail.com   Febrero     12/02/2024
# 1     Sergio Aguirre     Sergio_Aguirre@gmail.com   Febrero     12/02/2024
# 2    Carlito Carrión    Carlito_Carrión@gmail.com   Febrero     12/02/2024
# 3    Haydée Figueroa    Haydée_Figueroa@gmail.com   Febrero     12/02/2024
# 4      Chita Mancebo      Chita_Mancebo@gmail.com   Febrero     12/02/2024
# 5   Joaquina Asensio   Joaquina_Asensio@gmail.com   Febrero     12/02/2024
# 6   Cristian Sarabia   Cristian_Sarabia@gmail.com   Febrero     12/02/2024
# 7      Isabel Ibáñez      Isabel_Ibáñez@gmail.com   Febrero     12/02/2024
# 8    Desiderio Jordá    Desiderio_Jordá@gmail.com   Febrero     12/02/2024
# 9    Rosalina Llanos    Rosalina_Llanos@gmail.com   Febrero     12/02/2024
#
#    Campus Proyecto_HLF Proyecto_EDA Proyecto_BBDD Proyecto_ML  \
# 0  Madrid         Apto      No Apto       No Apto        Apto
# ...

# %%
clase_3 = pd.read_csv("./data/clase_3.csv", sep = ";")
clase_3
# Out:
#                 Nombre                         Email   Promoción  \
# 0       Amor Larrañaga      Amor_Larrañaga@gmail.com  Septiembre
# 1     Teodoro Alberola    Teodoro_Alberola@gmail.com  Septiembre
# 2          Cleto Plana         Cleto_Plana@gmail.com  Septiembre
# 3     Aitana Sebastián    Aitana_Sebastián@gmail.com  Septiembre
# 4     Dolores Valbuena    Dolores_Valbuena@gmail.com  Septiembre
# 5         Julie Ferrer        Julie_Ferrer@gmail.com  Septiembre
# 6       Mireia Cabañas      Mireia_Cabañas@gmail.com  Septiembre
# 7        Flavia Amador       Flavia_Amador@gmail.com  Septiembre
# 8        Albino Macias       Albino_Macias@gmail.com  Septiembre
# 9        Ester Sánchez       Ester_Sánchez@gmail.com  Septiembre
# 10  Luis Miguel Galvez  Luis_Miguel_Galvez@gmail.com  Septiembre
# 11      Loida Arellano      Loida_Arellano@gmail.com  Septiembre
# 12      Heraclio Duque      Heraclio_Duque@gmail.com  Septiembre
# ...

# %%
clase_4 = pd.read_csv("./data/clase_4.csv", sep = ";")
clase_4
# Out:
#                  Nombre                          Email Promoción  \
# 0         Teresa Laguna        Teresa_Laguna@gmail.com   Febrero
# 1      Estrella Murillo     Estrella_Murillo@gmail.com   Febrero
# 2       Ernesto Uriarte      Ernesto_Uriarte@gmail.com   Febrero
# 3       Daniela Guitart      Daniela_Guitart@gmail.com   Febrero
# 4        Timoteo Trillo       Timoteo_Trillo@gmail.com   Febrero
# 5         Ricarda Tovar        Ricarda_Tovar@gmail.com   Febrero
# 6   Alejandra Vilaplana  Alejandra_Vilaplana@gmail.com   Febrero
# 7       Daniel Rosselló      Daniel_Rosselló@gmail.com   Febrero
# 8         Rita Olivares        Rita_Olivares@gmail.com   Febrero
# 9          Cleto Montes         Cleto_Montes@gmail.com   Febrero
# 10      Marino Castilla      Marino_Castilla@gmail.com   Febrero
# 11  Estefanía Valcárcel  Estefanía_Valcárcel@gmail.com   Febrero
# 12       Noemí Vilanova       Noemí_Vilanova@gmail.com   Febrero
#
# ...

# %%
claustro = pd.read_csv("./data/claustro.csv", sep = ";")
claustro
# Out:
#                Nombre Rol Vertical   Promocion    Campus   Modalidad
# 0           Noa Yáñez  TA       DS  Septiembre    Madrid  Presencial
# 1   Saturnina Benitez  TA       DS  Septiembre    Madrid  Presencial
# 2          Anna Feliu  TA       FS  Septiembre    Madrid  Presencial
# 3       Rosalva Ayuso  TA       FS  Septiembre  Valencia  Presencial
# 4    Ana Sofía Ferrer  TA       FS     Febrero  Valencia  Presencial
# 5     Angélica Corral  TA       FS     Febrero    Madrid  Presencial
# 6         Ariel Lledó  TA       DS  Septiembre    Madrid  Presencial
# 7         Mario Prats  LI       FS     Febrero  Valencia      Online
# 8   Luis Ángel Suárez  LI       FS  Septiembre    Madrid      Online
# 9  María Dolores Diaz  LI       DS  Septiembre    Madrid      Online

# %%
claustro_promocion = claustro[['Vertical','Promocion','Campus','Modalidad']]
claustro_promocion2= claustro_promocion.loc[2:]

# %%
clau3 = claustro_promocion2.sort_values("Promocion")
clau3["fecha"]=["12/02/2024","12/02/2024","12/02/2024","18/09/2023","18/09/2023","18/09/2023","18/09/2023","18/09/2023"]
clau3
# Out:
#   Vertical   Promocion    Campus   Modalidad       fecha
# 4       FS     Febrero  Valencia  Presencial  12/02/2024
# 5       FS     Febrero    Madrid  Presencial  12/02/2024
# 7       FS     Febrero  Valencia      Online  12/02/2024
# 2       FS  Septiembre    Madrid  Presencial  18/09/2023
# 3       FS  Septiembre  Valencia  Presencial  18/09/2023
# 6       DS  Septiembre    Madrid  Presencial  18/09/2023
# 8       FS  Septiembre    Madrid      Online  18/09/2023
# 9       DS  Septiembre    Madrid      Online  18/09/2023

# %%
clau3 = clau3.rename(columns={"Vertical":"vertical","Promocion":"mes_promo","Campus":"campus","Modalidad":"modalidad"})

# %%
clau3.to_csv("claustro.csv",index=False)

# %%
clau3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 4 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   vertical   8 non-null      object
#  1   mes_promo  8 non-null      object
#  2   campus     8 non-null      object
#  3   modalidad  8 non-null      object
#  4   fecha      8 non-null      object
# dtypes: object(5)
# memory usage: 384.0+ bytes

# %%
clau3["fecha"]=pd.to_datetime(clau3["fecha"], format='%d/%m/%Y')
clau3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 4 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   vertical   8 non-null      object
#  1   mes_promo  8 non-null      object
#  2   campus     8 non-null      object
#  3   modalidad  8 non-null      object
#  4   fecha      8 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 384.0+ bytes

# %%
clau3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 4 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   vertical   8 non-null      object
#  1   mes_promo  8 non-null      object
#  2   campus     8 non-null      object
#  3   modalidad  8 non-null      object
#  4   fecha      8 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 384.0+ bytes

# %%
clau3.to_csv("claustro.csv",index=False)

# %%
clau4 = claustro[['Nombre','Rol']]
clau4
# Out:
#                Nombre Rol
# 0           Noa Yáñez  TA
# 1   Saturnina Benitez  TA
# 2          Anna Feliu  TA
# 3       Rosalva Ayuso  TA
# 4    Ana Sofía Ferrer  TA
# 5     Angélica Corral  TA
# 6         Ariel Lledó  TA
# 7         Mario Prats  LI
# 8   Luis Ángel Suárez  LI
# 9  María Dolores Diaz  LI

# %%
clau4 = clau4.rename(columns={"Nombre":"nombre","Rol":"rol"})

# %%
clau4.to_csv("claustro2.csv",index=False)

# %%
clase12 = pd.concat([clase_1, clase_2], ignore_index=True)
clase12
# Out:
#                   Nombre                           Email   Promoción  \
# 0           Jafet Casals          Jafet_Casals@gmail.com  Septiembre
# 1       Jorge Manzanares      Jorge_Manzanares@gmail.com  Septiembre
# 2          Onofre Adadia         Onofre_Adadia@gmail.com  Septiembre
# 3           Merche Prada          Merche_Prada@gmail.com  Septiembre
# 4           Pilar Abella          Pilar_Abella@gmail.com  Septiembre
# 5           Leoncio Tena          Leoncio_Tena@gmail.com  Septiembre
# 6        Odalys Torrijos       Odalys_Torrijos@gmail.com  Septiembre
# 7       Eduardo Caparrós      Eduardo_Caparrós@gmail.com  Septiembre
# 8     Ignacio Goicoechea    Ignacio_Goicoechea@gmail.com  Septiembre
# 9      Clementina Santos     Clementina_Santos@gmail.com  Septiembre
# 10         Daniela Falcó         Daniela_Falcó@gmail.com  Septiembre
# 11         Abraham Vélez         Abraham_Vélez@gmail.com  Septiembre
# 12  Maximiliano Menéndez  Maximiliano_Menéndez@gmail.com  Septiembre
# ...

# %%
clase12b = clase12[['Nombre','Email']]
clase12b
# Out:
#                   Nombre                           Email
# 0           Jafet Casals          Jafet_Casals@gmail.com
# 1       Jorge Manzanares      Jorge_Manzanares@gmail.com
# 2          Onofre Adadia         Onofre_Adadia@gmail.com
# 3           Merche Prada          Merche_Prada@gmail.com
# 4           Pilar Abella          Pilar_Abella@gmail.com
# 5           Leoncio Tena          Leoncio_Tena@gmail.com
# 6        Odalys Torrijos       Odalys_Torrijos@gmail.com
# 7       Eduardo Caparrós      Eduardo_Caparrós@gmail.com
# 8     Ignacio Goicoechea    Ignacio_Goicoechea@gmail.com
# 9      Clementina Santos     Clementina_Santos@gmail.com
# 10         Daniela Falcó         Daniela_Falcó@gmail.com
# 11         Abraham Vélez         Abraham_Vélez@gmail.com
# 12  Maximiliano Menéndez  Maximiliano_Menéndez@gmail.com
# 13         Anita Heredia         Anita_Heredia@gmail.com
# 14             Eli Casas             Eli_Casas@gmail.com
# ...

# %%
clase12b = clase12b.rename(columns={"Nombre":"nombre","Email":"email"})

# %%
clase34 = pd.concat([clase_3, clase_4], ignore_index=True)
clase34
# Out:
#                  Nombre                          Email   Promoción  \
# 0        Amor Larrañaga       Amor_Larrañaga@gmail.com  Septiembre
# 1      Teodoro Alberola     Teodoro_Alberola@gmail.com  Septiembre
# 2           Cleto Plana          Cleto_Plana@gmail.com  Septiembre
# 3      Aitana Sebastián     Aitana_Sebastián@gmail.com  Septiembre
# 4      Dolores Valbuena     Dolores_Valbuena@gmail.com  Septiembre
# 5          Julie Ferrer         Julie_Ferrer@gmail.com  Septiembre
# 6        Mireia Cabañas       Mireia_Cabañas@gmail.com  Septiembre
# 7         Flavia Amador        Flavia_Amador@gmail.com  Septiembre
# 8         Albino Macias        Albino_Macias@gmail.com  Septiembre
# 9         Ester Sánchez        Ester_Sánchez@gmail.com  Septiembre
# 10   Luis Miguel Galvez   Luis_Miguel_Galvez@gmail.com  Septiembre
# 11       Loida Arellano       Loida_Arellano@gmail.com  Septiembre
# 12       Heraclio Duque       Heraclio_Duque@gmail.com  Septiembre
# ...

# %%
clase34b = clase34[['Nombre','Email']]
clase34b
# Out:
#                  Nombre                          Email
# 0        Amor Larrañaga       Amor_Larrañaga@gmail.com
# 1      Teodoro Alberola     Teodoro_Alberola@gmail.com
# 2           Cleto Plana          Cleto_Plana@gmail.com
# 3      Aitana Sebastián     Aitana_Sebastián@gmail.com
# 4      Dolores Valbuena     Dolores_Valbuena@gmail.com
# 5          Julie Ferrer         Julie_Ferrer@gmail.com
# 6        Mireia Cabañas       Mireia_Cabañas@gmail.com
# 7         Flavia Amador        Flavia_Amador@gmail.com
# 8         Albino Macias        Albino_Macias@gmail.com
# 9         Ester Sánchez        Ester_Sánchez@gmail.com
# 10   Luis Miguel Galvez   Luis_Miguel_Galvez@gmail.com
# 11       Loida Arellano       Loida_Arellano@gmail.com
# 12       Heraclio Duque       Heraclio_Duque@gmail.com
# 13    Herberto Figueras    Herberto_Figueras@gmail.com
# 14        Teresa Laguna        Teresa_Laguna@gmail.com
# 15     Estrella Murillo     Estrella_Murillo@gmail.com
# ...

# %%
clase34b = clase34b.rename(columns={"Nombre":"nombre","Email":"email"})
clase34b
# Out:
#                  nombre                          email
# 0        Amor Larrañaga       Amor_Larrañaga@gmail.com
# 1      Teodoro Alberola     Teodoro_Alberola@gmail.com
# 2           Cleto Plana          Cleto_Plana@gmail.com
# 3      Aitana Sebastián     Aitana_Sebastián@gmail.com
# 4      Dolores Valbuena     Dolores_Valbuena@gmail.com
# 5          Julie Ferrer         Julie_Ferrer@gmail.com
# 6        Mireia Cabañas       Mireia_Cabañas@gmail.com
# 7         Flavia Amador        Flavia_Amador@gmail.com
# 8         Albino Macias        Albino_Macias@gmail.com
# 9         Ester Sánchez        Ester_Sánchez@gmail.com
# 10   Luis Miguel Galvez   Luis_Miguel_Galvez@gmail.com
# 11       Loida Arellano       Loida_Arellano@gmail.com
# 12       Heraclio Duque       Heraclio_Duque@gmail.com
# 13    Herberto Figueras    Herberto_Figueras@gmail.com
# 14        Teresa Laguna        Teresa_Laguna@gmail.com
# 15     Estrella Murillo     Estrella_Murillo@gmail.com
# ...

# %%
nombremail = pd.concat([clase12b, clase34b], ignore_index=True)
nombremail
# Out:
#                   nombre                           email
# 0           Jafet Casals          Jafet_Casals@gmail.com
# 1       Jorge Manzanares      Jorge_Manzanares@gmail.com
# 2          Onofre Adadia         Onofre_Adadia@gmail.com
# 3           Merche Prada          Merche_Prada@gmail.com
# 4           Pilar Abella          Pilar_Abella@gmail.com
# 5           Leoncio Tena          Leoncio_Tena@gmail.com
# 6        Odalys Torrijos       Odalys_Torrijos@gmail.com
# 7       Eduardo Caparrós      Eduardo_Caparrós@gmail.com
# 8     Ignacio Goicoechea    Ignacio_Goicoechea@gmail.com
# 9      Clementina Santos     Clementina_Santos@gmail.com
# 10         Daniela Falcó         Daniela_Falcó@gmail.com
# 11         Abraham Vélez         Abraham_Vélez@gmail.com
# 12  Maximiliano Menéndez  Maximiliano_Menéndez@gmail.com
# 13         Anita Heredia         Anita_Heredia@gmail.com
# 14             Eli Casas             Eli_Casas@gmail.com
# ...

# %%
nombremail.to_csv("alumnos.csv",index=False)

# %%
listaproyectosa = clase12.columns.to_list()

# %%
listaproyectosab= listaproyectosa[5:]

# %%
listaproyectosb = clase34.columns.to_list()

# %%
listaproyectosba= listaproyectosb[5:]
listaproyectosba
# Out:
# ['Proyecto_WebDev',
#  'Proyecto_FrontEnd',
#  'Proyecto_Backend',
#  'Proyecto_React',
#  'Proyecto_FullSatck']

# %%
listac= listaproyectosab+listaproyectosba

# %%
listad= pd.DataFrame({"nombre":listac})
listad
# Out:
#                 nombre
# 0         Proyecto_HLF
# 1         Proyecto_EDA
# 2        Proyecto_BBDD
# 3          Proyecto_ML
# 4  Proyecto_Deployment
# 5      Proyecto_WebDev
# 6    Proyecto_FrontEnd
# 7     Proyecto_Backend
# 8       Proyecto_React
# 9   Proyecto_FullSatck

# %%
listad.to_csv("listaproyectos.csv",index=False)

# %%
list_of_lists = df.values.tolist()

# %%
print(clase12.columns)
# Out:
# Index(['Nombre', 'Email', 'Promoción', 'Fecha_comienzo', 'Campus',
#        'Proyecto_HLF', 'Proyecto_EDA', 'Proyecto_BBDD', 'Proyecto_ML',
#        'Proyecto_Deployment'],
#       dtype='object')

# %%
clase12c = clase12[["Proyecto_HLF","Proyecto_EDA","Proyecto_BBDD","Proyecto_ML","Proyecto_Deployment"]]
clase12c
# Out:
#    Proyecto_HLF Proyecto_EDA Proyecto_BBDD Proyecto_ML Proyecto_Deployment
# 0          Apto      No Apto          Apto        Apto                Apto
# 1          Apto      No Apto          Apto        Apto                Apto
# 2          Apto         Apto          Apto     No Apto                Apto
# 3          Apto      No Apto       No Apto        Apto             No Apto
# 4          Apto      No Apto          Apto        Apto                Apto
# 5          Apto         Apto          Apto        Apto                Apto
# 6       No Apto         Apto          Apto        Apto                Apto
# 7       No Apto         Apto          Apto        Apto                Apto
# 8          Apto         Apto          Apto     No Apto                Apto
# 9          Apto      No Apto          Apto        Apto                Apto
# 10         Apto         Apto          Apto        Apto                Apto
# ...

# %%
list_of_notas12 = clase12c.values.tolist()
print(list_of_notas12)
# Out:
# [['Apto', 'No Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'No Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'Apto', 'No Apto', 'Apto'], ['Apto', 'No Apto', 'No Apto', 'Apto', 'No Apto'], ['Apto', 'No Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['No Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['No Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'Apto', 'No Apto', 'Apto'], ['Apto', 'No Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'No Apto', 'No Apto', 'Apto', 'Apto'], ['Apto', 'No Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'No Apto', 'No Apto', 'Apto', 'No Apto'], ['Apto', 'No Apto', 'Apto', 'Apto', 'No Apto'], ['Apto', 'No Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['No Apto', 'Apto', 'No Apto', 'Apto', 'Apto'], ['No Apto', 'No Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'No Apto', 'Apto', 'Apto']
# ...

# %%
clase34c=clase34[["Proyecto_WebDev","Proyecto_FrontEnd","Proyecto_Backend","Proyecto_React","Proyecto_FullSatck"]]
clase34c
# Out:
#    Proyecto_WebDev Proyecto_FrontEnd Proyecto_Backend Proyecto_React  \
# 0             Apto              Apto             Apto           Apto
# 1          No Apto           No Apto             Apto        No Apto
# 2             Apto           No Apto             Apto        No Apto
# 3             Apto           No Apto             Apto        No Apto
# 4             Apto              Apto             Apto           Apto
# 5          No Apto           No Apto          No Apto           Apto
# 6          No Apto              Apto             Apto           Apto
# 7             Apto              Apto          No Apto           Apto
# 8          No Apto              Apto             Apto           Apto
# 9          No Apto              Apto             Apto        No Apto
# 10         No Apto              Apto             Apto           Apto
# 11            Apto              Apto             Apto           Apto
# 12            Apto              Apto          No Apto        No Apto
# ...

# %%
list_of_notas34 = clase34c.values.tolist()
print(list_of_notas34)
# Out:
# [['Apto', 'Apto', 'Apto', 'Apto', 'No Apto'], ['No Apto', 'No Apto', 'Apto', 'No Apto', 'Apto'], ['Apto', 'No Apto', 'Apto', 'No Apto', 'Apto'], ['Apto', 'No Apto', 'Apto', 'No Apto', 'Apto'], ['Apto', 'Apto', 'Apto', 'Apto', 'No Apto'], ['No Apto', 'No Apto', 'No Apto', 'Apto', 'No Apto'], ['No Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'No Apto', 'Apto', 'Apto'], ['No Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['No Apto', 'Apto', 'Apto', 'No Apto', 'Apto'], ['No Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'No Apto', 'No Apto', 'No Apto'], ['Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'No Apto', 'Apto', 'Apto'], ['Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['Apto', 'No Apto', 'No Apto', 'Apto', 'Apto'], ['No Apto', 'Apto', 'Apto', 'Apto', 'No Apto'], ['Apto', 'Apto', 'Apto', 'Apto', 'Apto'], ['No Apto', 'No Apto', 'No Apto', 'Apto', 'Apto'], ['No Apto', 'No Apto', 'A
# ...

# %%
list_of_notes=list_of_notas12+list_of_notas34

# %%
flat_list = [item for sublist in list_of_notes for item in sublist]

# %%
list_of_notes2 = pd.DataFrame({"notas":flat_list})
list_of_notes2.head(10)
# Out:
#      notas
# 0     Apto
# 1  No Apto
# 2     Apto
# 3     Apto
# 4     Apto
# 5     Apto
# 6  No Apto
# 7     Apto
# 8     Apto
# 9     Apto

# %%
list_of_notes2.to_csv("notas.csv",index=False)
